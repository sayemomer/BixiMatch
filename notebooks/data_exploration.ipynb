# %% [markdown]
# ### Step:1- load the 2014 bike use data with weather

# %%
import pandas as pd
import numpy as np

def load_data():
    data = pd.read_csv('/Users/sayems_mac/BixiMatch/data/OD/OD_2014_weather_agg.csv')
    return data


df = load_data()

df.head()
# Out:
#    num_week  weekday  hour      Description  Temperature  Pressure  \
# 0        16        1     3       light rain       288.05    1003.0
# 1        16        1     6       light rain       287.31    1003.0
# 2        16        1     8       light rain       286.64    1002.0
# 3        16        1     9       light rain       286.74    1002.0
# 4        16        1    11  overcast clouds       287.70     997.0
#
#    Wind_speed  count
# 0         5.0      1
# 1         3.0      2
# 2         3.0      4
# 3         3.0      6
# 4         9.0      1

# %% [markdown]
# ### Step:2- Number of trips by weather description

# %%
# graph the number of trips by weather condition

import matplotlib.pyplot as plt

df['Description'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Step:3- Number of trips by temperature

# %%
# graph the temperature to number of trips distribution

df['Temperature'].hist(bins=20)

plt.show()

# %% [markdown]
# ### Step:4- Number of trips by wind speed

# %%
# graph the number of trips by precipitation

df['Wind_speed'].hist(bins=20)

plt.show()

# %% [markdown]
# ### Step:5- Number of trips by weekday

# %%
# graph the number of trips by days of the week by a line graph

df['num_week'].value_counts().plot(kind='line')
plt.show()

# %%
# weekday vs weekend

df['weekend'] = df['weekday'].apply(lambda x: 1 if x >= 5 else 0)

df['weekend'].value_counts().plot(kind='bar')

plt.show()

# %% [markdown]
# ### Step:7- Time series analysis

# %%
# check seasonality by a line graph

df['hour'].value_counts().plot(kind='line')
plt.show()
